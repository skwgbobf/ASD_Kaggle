# %% [markdown]
# 3. Kaggle2_children_QCHAT_preporicessing
# The children Kaggle Dataset (QCHAT with additional features) served as input. ASD-specific terms were mapped onto the existing features to create an enhanced dataset tailored for deep learning classification model development
#
#
# - Soo Kyung Bae(Scarlett), Ph.D. Student
# - Dept. of Integrated Medicine(Major in Digital Healthcare)
# - Yonsei University College of Medicine

# %%
## Import Data

import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
pt ='/home/skbae/Desktop/146/ASD/NLP/ASD_TD/Kaggle_data'

# %%
#Reading the train file
qchat= pd.read_csv(pt + "/qchat.csv")

# %%
qchat.head()
# Out:
#   Var                                        Q_chat_10_T
# 0  A1   Does your child look at you when you call his...
# 1  A2  How easy is it for you to get eye contact with...
# 2  A3  Does your child point to indicate that s/he wa...
# 3  A4  Does your child point to share interest with y...
# 4  A5  Does your child pretend? (e.g. care for dolls,...

# %%
# QCHT_ASD term

# QCHAT_ASD_terms.csv
#Reading the train file
QCHAT_ASD_t= pd.read_csv(pt + "/QCHAT_ASD_Term1.csv")

# %%
QCHAT_ASD_t
# Out:
#    Var                                        Q_chat_10_T       ID  \
# 0   A1  Does your child look at you when you call his/...  ASD0194
# 1   A2  How easy is it for you to get eye contact with...  ASD0250
# 2   A3  Does your child point to indicate that s/he wa...    S1049
# 3   A4  Does your child point to share interest with y...    S0769
# 4   A5  Does your child pretend? (e.g. care for dolls,...    S1268
# 5   A6       Does your child follow where you’re looking?  ASD0642
# 6   A7  If you or someone else in the family is visibl...  ASD0019
# 7   A8    Would you describe your child’s first words as:  ASD0372
# 8   A9  Does your child use simple gestures? (e.g. wav...  ASD0216
# 9  A10  Does your child stare at nothing with no appar...  ASD0350
#
#                                                 Name DSM5 Criteria  \
# 0                attention and concentration deficit            A2
# 1                                       contacts eye            A2
# ...

# %%
# https://www.kaggle.com/datasets/uppulurimadhuri/dataset
#data_csv
"""
This dataset contains factors involved in developing ASD in children. It consists of the following features:
A10 Autism Spectrum Quotient, Social Responsiveness Scale, Age Years, 
Qchat_10_Score, Speech Delay/Language Disorder, Learning disorder, Genetic Disorders,Depression, 
Global developmental delay/intellectual disability, Social/Behavioural Issues, Childhood Autism Rating Scale, 
Anxiety disorder, Sex, Ethnicity, Jaundice, Family mem with ASD along with various information
The data here consists of different quantities and factors which have characteristics of ASD in children. 
It is collected from AUTISM RESEARCH: UNIVERSITY OF ARKANSAS Computer Science Dept to analyze the disease 
conditions and predict them in beforehand

"""

ASD_data_csv= pd.read_csv(pt + "/data_csv.csv")

# %%
ASD_data_csv.head()
print(len(ASD_data_csv))
# Out:
# 1985

# %% [markdown]
# """
# A1-A10: Items within Q-Chat-10  in which questions possible answers :
# “Always, Usually, Sometimes, Rarly & Never” items’ values are mapped to “1” or “0” in the dataset.
#
# For questions 1-9 (A1-A9) in Q-chat-10,  if the respose was  Sometimes / Rarly / Never “1” is assigned to the question (A1-A9).
# However, for question 10 (A10), if the respose was Always / Usually / Sometimes then “1” is assigned to that question.
# If the user obtained More than 3 Add points together for all ten questions.
# If your child scores more than 3 (Q-chat-10- score) then there is a potential ASD traits otherwise no ASD traits are observed.
#
#
# """

# %%
ASD_data_csv.head()
# Out:
#    CASE_NO_PATIENT'S  A1  A2  A3  A4  A5  A6  A7  A8  A9  ...  \
# 0                  1   0   0   0   0   0   0   1   1   0  ...
# 1                  2   1   1   0   0   0   1   1   0   0  ...
# 2                  3   1   0   0   0   0   0   1   1   0  ...
# 3                  4   1   1   1   1   1   1   1   1   1  ...
# 4                  5   1   1   0   1   1   1   1   1   1  ...
#
#    Global developmental delay/intellectual disability  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#    Social/Behavioural Issues  Childhood Autism Rating Scale  Anxiety_disorder  \
# 0                        Yes                              1               Yes
# 1                        Yes                              2               Yes
# ...

# %%
QCHAT_ASD_t.columns
# Out:
# Index(['Var', 'Q_chat_10_T', 'ID', 'Name', 'DSM5 Criteria',
#        'Symptom of DSM5 Criteria', 'CUI'],
#       dtype='object')

# %%
QCHAT_ASD_t[['Var','Name','CUI']]
# Out:
#    Var                                               Name       CUI
# 0   A1                attention and concentration deficit  C2977673
# 1   A2                                       contacts eye  C0870532
# 2   A3                             spontaneously pointing  C4036288
# 3   A4                       pointing to express interest  C0424091
# 4   A5                                  does pretend play  C2371970
# 5   A6                                 shifting attention  C2370875
# 6   A7  social interaction impairment in social/emotio...  C4064035
# 7   A8                                      absent speech  C1854882
# 8   A9                       difficulty imitating gesture  C0566243
# 9  A10  play impairment stares blankly at play objects...  C4064319

# %%
QCHAT_ASD_t['Name'][9]
# Out:
# 'play impairment stares blankly at play objects rather than manipulating them'

# %%
ASD_data_csv.columns
# Out:
# Index(['CASE_NO_PATIENT'S', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8',
#        'A9', 'A10_Autism_Spectrum_Quotient', 'Social_Responsiveness_Scale',
#        'Age_Years', 'Qchat_10_Score', 'Speech Delay/Language Disorder',
#        'Learning disorder', 'Genetic_Disorders', 'Depression',
#        'Global developmental delay/intellectual disability',
#        'Social/Behavioural Issues', 'Childhood Autism Rating Scale',
#        'Anxiety_disorder', 'Sex', 'Ethnicity', 'Jaundice',
#        'Family_mem_with_ASD', 'Who_completed_the_test', 'ASD_traits'],
#       dtype='object')

# %%
T_ASD2=ASD_data_csv

# %%
T_ASD2['A1_C2977673']=['attention and concentration deficit' if x ==1 else '' for x in T_ASD2['A1']]

# %%
T_ASD2['A2_C0870532']=['contacts eye' if x ==1 else '' for x in T_ASD2['A2']]
T_ASD2['A3_C4036288']=['spontaneously pointing' if x ==1 else '' for x in T_ASD2['A3']]
T_ASD2['A4_C0424091']=['pointing to express interest' if x ==1 else '' for x in T_ASD2['A4']]
T_ASD2['A5_C2371970']=['does pretend play' if x ==1 else '' for x in T_ASD2['A5']]
T_ASD2['A6_C2370875']=['shifting attention' if x ==1 else '' for x in T_ASD2['A6']]
T_ASD2['A7_C4064035']=['social interaction impairment in social/emotional reciprocity' if x ==1 else '' for x in T_ASD2['A7']]
T_ASD2['A8_C1854882']=['absent speech' if x ==1 else '' for x in T_ASD2['A8']]
T_ASD2['A9_C0566243']=['difficulty imitating gesture' if x ==1 else '' for x in T_ASD2['A9']]
T_ASD2['A10_C4064319']=['play impairment stares blankly at play objects rather than manipulating them' if x ==1 else '' for x in T_ASD2['A10_Autism_Spectrum_Quotient']]

# %%
T_ASD2.head()
# Out:
#    CASE_NO_PATIENT'S  A1  A2  A3  A4  A5  A6  A7  A8  A9  ...  \
# 0                  1   0   0   0   0   0   0   1   1   0  ...
# 1                  2   1   1   0   0   0   1   1   0   0  ...
# 2                  3   1   0   0   0   0   0   1   1   0  ...
# 3                  4   1   1   1   1   1   1   1   1   1  ...
# 4                  5   1   1   0   1   1   1   1   1   1  ...
#
#                            A1_C2977673   A2_C0870532             A3_C4036288  \
# 0
# 1  attention and concentration deficit  contacts eye
# 2  attention and concentration deficit
# 3  attention and concentration deficit  contacts eye  spontaneously pointing
# 4  attention and concentration deficit  contacts eye
#
#                     A4_C0424091        A5_C2371970         A6_C2370875  \
# 0
# 1                                                   shifting attention
# 2
# 3  pointing to express interest  does pretend play  shifting attention
# ...

# %%
T_ASD2.columns
# Out:
# Index(['CASE_NO_PATIENT'S', 'A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8',
#        'A9', 'A10_Autism_Spectrum_Quotient', 'Social_Responsiveness_Scale',
#        'Age_Years', 'Qchat_10_Score', 'Speech Delay/Language Disorder',
#        'Learning disorder', 'Genetic_Disorders', 'Depression',
#        'Global developmental delay/intellectual disability',
#        'Social/Behavioural Issues', 'Childhood Autism Rating Scale',
#        'Anxiety_disorder', 'Sex', 'Ethnicity', 'Jaundice',
#        'Family_mem_with_ASD', 'Who_completed_the_test', 'ASD_traits',
#        'A1_C2977673', 'A2_C0870532', 'A3_C4036288', 'A4_C0424091',
#        'A5_C2371970', 'A6_C2370875', 'A7_C4064035', 'A8_C1854882',
#        'A9_C0566243', 'A10_C4064319'],
#       dtype='object')

# %%
T_ASD2['combined']=T_ASD2[[T_ASD2.columns[28],T_ASD2.columns[29],T_ASD2.columns[30],\
                         T_ASD2.columns[31],T_ASD2.columns[32],T_ASD2.columns[33],\
                        T_ASD2.columns[34],T_ASD2.columns[35],T_ASD2.columns[36],\
                        T_ASD2.columns[37]]].apply(lambda x: " ,".join(x), axis =1)

# %%
T_ASD2[['A1_C2977673', 'A2_C0870532','combined']].head()
# Out:
#                            A1_C2977673   A2_C0870532  \
# 0
# 1  attention and concentration deficit  contacts eye
# 2  attention and concentration deficit
# 3  attention and concentration deficit  contacts eye
# 4  attention and concentration deficit  contacts eye
#
#                                             combined
# 0   , , , , , ,social interaction impairment in s...
# 1  attention and concentration deficit ,contacts ...
# 2  attention and concentration deficit , , , , , ...
# 3  attention and concentration deficit ,contacts ...
# 4  attention and concentration deficit ,contacts ...

# %%
# Export :
T_ASD2.to_csv('./ASD_CSV_T_ASD2_Feb23.csv', index=False)

# %%
# import pandas as pd

# T_ASD2 = pd.read_csv('./ASD_CSV_T_ASD2_Feb23.csv')
